# %%
import pandas as pd

# %%
data_dictionary = pd.DataFrame([
    {
        'variavel': 'name',
        'descricao': 'Nome da mistura do café',
        'tipo': 'qualitativa',
        'subtipo': 'nominal',
    },
    {
        'variavel': 'roaster',
        'descricao': 'Nome do torrefador do café, o lugar que faz a torra dos grãos.',
        'tipo': 'qualitativa',
        'subtipo': 'nominal',
    },
    {
        'variavel': 'roast',
        'descricao': 'Tipo da torra',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal',
    },
    {
        'variavel': 'loc_country',
        'descricao': 'Localização onde se encontra o torrefador do café.',
        'tipo': 'qualitativa',
        'subtipo': 'nominal',
    },
    {
        'variavel': 'origin',
        'descricao': 'País de origem dos grãos',
        'tipo': 'qualitativa',
        'subtipo': 'nominal',
    },
    {
        'variavel': '100g_USD',
        'descricao': 'Preço por 100g dos grãos em dólar americano',
        'tipo': 'quantitativa',
        'subtipo': 'contínua',
    },
    {
        'variavel': 'rating',
        'descricao': 'Nota do café',
        'tipo': 'quantitativa',
        'subtipo': 'discreta',
    },
    {
        'variavel': 'review_date',
        'descricao': 'Data da avaliação do café',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal',
    },
    {
        'variavel': 'review',
        'descricao': 'Descrição da avaliação feita.',
        'tipo': 'qualitativa',
        'subtipo': 'nominal',
    }
    
])

# %%
data_dictionary
# Out:
#       variavel                                          descricao  \
# 0         name                            Nome da mistura do café
# 1      roaster  Nome do torrefador do café, o lugar que faz a ...
# 2        roast                                      Tipo da torra
# 3  loc_country  Localização onde se encontra o torrefador do c...
# 4       origin                           País de origem dos grãos
# 5     100g_USD        Preço por 100g dos grãos em dólar americano
# 6       rating                                       Nota do café
# 7  review_date                          Data da avaliação do café
# 8       review                      Descrição da avaliação feita.
#
#            tipo   subtipo
# 0   qualitativa   nominal
# 1   qualitativa   nominal
# 2   qualitativa   ordinal
# 3   qualitativa   nominal
# 4   qualitativa   nominal
# 5  quantitativa  contínua
# 6  quantitativa  discreta
# 7   qualitativa   ordinal
# 8   qualitativa   nominal

# %%
data_dictionary.to_csv("../data/external/dictionary.csv", index=False)
